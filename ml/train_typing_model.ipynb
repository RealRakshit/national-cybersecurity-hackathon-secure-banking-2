# %% [markdown]
# # Typing behavior model
#
# Train a generic anomaly detector over robust shifts from each user's five accepted login profiles and export the pickle artifact used by the Express login route.

# %%
from train_typing_model import MODEL_PATH, build_training_matrix, export_model, train_model

training_matrix = build_training_matrix()
training_matrix.shape

# %%
model = train_model()
export_model(model, MODEL_PATH)
